# %% [markdown]
# 1. Pandas -> Data collection/Data Manipulation
# 2. Numpy -> To convert above data into numerical format such as matrix, vector, scalar, and tensor (Data Structures such as nd.array)
# 3. Matplotlib, seaborn -> Data visualization
# 4. Scikit-learn -> machine learning Algorithm implementation: supervised or unsupervided (Regression, Classification, Clustering, Dimensionally)
# 5. Tensorflow(developed by google)/ Pytorch(developed by Meta) -> Framework for deep learning Algorithm implementation: ANN, CNN, RNN, LSTM
# 6. Langchain -> framework for generative AI and LLM's : to build applications using LLM's like  chatbots, Text generation

# %%
# we have roles in market
# Data Engineer -->
