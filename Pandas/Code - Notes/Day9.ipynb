# %% [markdown]
# 1. Problem Definiation: it should not be more than 2 lines of text
# 2. Data Acquistion/collection: Getting data from the customers
# 3. Data Exploration & Profiling:
# 4. Data cleaning & pre-processing:
# 5. Feature Engineering:
# 6. Feature Selection/Extraction:
# 7. Encoding & Representation:
# 8. Train-Test-Split & Validation
# 9. Model Training
# 10. Model Evaluation
# 11. Model Selection & Finalization
# 12. Model Deploy
# 13. Maintainance & Continuous learning
# 14. Documentation & Communication

# %% [markdown]
# # The package: libraries we going to use for data collection and data manipulation as pandas
# # installing PANDAS
# # please use the following command

# %%
# %pip install pandas
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.1 MB 2.1 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/11.1 MB 2.4 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.1 MB 2.4 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/11.1 MB 2.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.9/11.1 MB 2.6 MB/s eta 0:00:04
#    ------------- -------------------------- 3.7/11.1 MB 2.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.5/11.1 MB 2.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.0/11.1 MB 2.8 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.1 MB 2.9 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
#f means format string
print(f"The installed version of the pandas is : {pd.__version__}")
# Out:
# The installed version of the pandas is : 2.3.3
