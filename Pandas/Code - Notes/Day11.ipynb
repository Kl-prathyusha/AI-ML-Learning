# %%
# %pip install -qU pandas
# %pip install -qU numpy
# %pip install -qU matplotlib
# %pip install -qU seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\klpra\AppData\Local\Programs\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd # for Data collection and manipulation
import numpy as np # converting data into numbers
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # data visualization

# %%
df = pd.read_csv(r'C:\Users\klpra\OneDrive\Desktop\Course\Documents\Pandas\titanic.csv')

# %%
df['Name'].count() #count of Rows
# Out:
# np.int64(891)

# %%
df['Age'].unique() #unique values in Age column
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df['Survived'].count() #count of Rows
# Out:
# np.int64(891)

# %%
df['Survived'].unique() #unique values in Survived column
# Out:
# array([0, 1])

# %%
df['Survived'].value_counts() #count of unique values in Survived column
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Age'].value_counts() #count of unique values in Age column
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
print(df['Age'].mean()) #sum of values/number of values
# Out:
# 29.69911764705882

# %%
df['Age'].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
df['Age'].describe() #this commands shows only numerical columns
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
len(df.describe())
#number of columns in describe()
# Out:
# 8

# %%
len(df.columns)
# Out:
# 12

# %%
df[['Age','Survived']] #multiple columns selection
# Out:
#       Age  Survived
# 0    22.0         0
# 1    38.0         1
# 2    26.0         1
# 3    35.0         1
# 4    35.0         0
# ..    ...       ...
# 886  27.0         0
# 887  19.0         1
# 888   NaN         0
# 889  26.0         1
# 890  32.0         0
#
# [891 rows x 2 columns]

# %%
df[['Age','Name','Survived']].dtypes #multiple columns selection
# Out:
# Age         float64
# Name         object
# Survived      int64
# dtype: object

# %%
df.iloc[700] #row selection by index
# Out:
# PassengerId                                                  701
# Survived                                                       1
# Pclass                                                         1
# Name           Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# Sex                                                       female
# Age                                                         18.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17757
# Fare                                                     227.525
# Cabin                                                    C62 C64
# Embarked                                                       C
# Name: 700, dtype: object

# %%
df.iloc[700:710] #multiple row selection by index
# Out:
#      PassengerId  Survived  Pclass  \
# 700          701         1       1
# 701          702         1       1
# 702          703         0       3
# 703          704         0       3
# 704          705         0       3
# 705          706         0       2
# 706          707         1       2
# 707          708         1       1
# 708          709         1       1
# 709          710         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0      1
# 701                   Silverthorne, Mr. Spencer Victor    male  35.0      0
# 702                              Barbara, Miss. Saiide  female  18.0      0
# 703                              Gallagher, Mr. Martin    male  25.0      0
# 704                            Hansen, Mr. Henrik Juul    male  26.0      1
# 705     Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0      0
# ...

# %%
df.iloc[150:155, 3:] #multiple row and column selection by index
# Out:
#                                   Name     Sex   Age  SibSp  Parch  \
# 150         Bateman, Rev. Robert James    male  51.0      0      0
# 151  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1      0
# 152                   Meo, Mr. Alfonzo    male  55.5      0      0
# 153    van Billiard, Mr. Austin Blyler    male  40.5      0      2
# 154              Olsen, Mr. Ole Martin    male   NaN      0      0
#
#           Ticket     Fare Cabin Embarked
# 150  S.O.P. 1166  12.5250   NaN        S
# 151       113776  66.6000    C2        S
# 152   A.5. 11206   8.0500   NaN        S
# 153     A/5. 851  14.5000   NaN        S
# 154    Fa 265302   7.3125   NaN        S

# %%
df.loc[150:155, ['Age','Name','Survived']] #multiple row and column selection by labels
# Out:
#       Age                               Name  Survived
# 150  51.0         Bateman, Rev. Robert James         0
# 151  22.0  Pears, Mrs. Thomas (Edith Wearne)         1
# 152  55.5                   Meo, Mr. Alfonzo         0
# 153  40.5    van Billiard, Mr. Austin Blyler         0
# 154   NaN              Olsen, Mr. Ole Martin         0
# 155  51.0        Williams, Mr. Charles Duane         0

# %%
#finding finding missing values
df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df['Age'].isnull().sum() #total number of missing values in Age column
# Out:
# np.int64(177)

# %%
df[df['Age'].isnull()] #rows with missing values in Age column
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
#finding duplicate values
df['Age'].duplicated().sum() #total number of duplicate values in Age column
# Out:
# np.int64(802)

# %%
df['Age'].value_counts() #count of unique values in Age column
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df.isnull().sum() #total number of missing values in each column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[df['Age']>54]
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 54            55         0       1
# 94            95         0       3
# 96            97         0       1
# 116          117         0       3
# 152          153         0       3
# 170          171         0       1
# 174          175         0       1
# 195          196         1       1
# 232          233         0       2
# 252          253         0       1
# 268          269         1       1
# 275          276         1       1
# 280          281         0       3
# 326          327         0       3
# 366          367         1       1
# 438          439         0       1
# 456          457         0       1
# 467          468         0       1
# 483          484         1       3
# 487          488         0       1
# 492          493         0       1
# 493          494         0       1
# ...

# %%
df[df[df['Age'] > 54]['Sex'=='male']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\klpra\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ...
